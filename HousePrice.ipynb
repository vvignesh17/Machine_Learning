# %%
import matplotlib.pyplot as plt
import numpy as np 
from sklearn.model_selection import train_test_split
import pandas as pd
import seaborn as sns 
# %matplotlib inline

# %% [markdown]
# <hr>
# <br>
# <font color="red" size=5px><h1 align="center">Loading the train.csv file</h1>
#     </font>
#     <br>

# %%
df=pd.read_csv("train1.csv")
df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities    ...     PoolArea PoolQC Fence MiscFeature MiscVal  \
# 0         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 1         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 2         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 3         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 4         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
#
#   MoSold YrSold  SaleType  SaleCondition  SalePrice
# ...

# %% [markdown]
# <h3><br>
# Now find the number of columns and rows in the dataframe that is in the train1.csv file</h3>
# <br><br>

# %%
df.shape
# Out:
# (1460, 81)

# %% [markdown]
# <hr>Now let's see he column which has NAN elements in their column</hr>

# %%
cd=df.isnull().sum()
cd=cd[cd>0]
cd.sort_values(ascending=True)
# Out:
# Electrical         1
# MasVnrType         8
# MasVnrArea         8
# BsmtQual          37
# BsmtCond          37
# BsmtFinType1      37
# BsmtExposure      38
# BsmtFinType2      38
# GarageCond        81
# GarageQual        81
# GarageFinish      81
# GarageType        81
# GarageYrBlt       81
# LotFrontage      259
# FireplaceQu      690
# Fence           1179
# Alley           1369
# MiscFeature     1406
# PoolQC          1453
# dtype: int64

# %% [markdown]
# <b><b> DROP THE COLUMN IN WHICH ALL THE ELEMENTS ARE NaN

# %%
df=df.dropna(axis=1,how="all")

# %% [markdown]
# <b>Name of all the column

# %%
df.columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
# ...

# %% [markdown]
# <body>
#     <h1 align="center"><font color="red"> DATA VISUALISATION</font></h1>
#     <h3><font color="green"> Using of countplot in seaborn library to visualise the plot between count and other feature</font </h3>
#  </body>

# %%
sns.countplot(df["HeatingQC"],label="Count")

# %%
d1={"Ex":5,"Gd":4,"TA":3,"Fa":2,"Po":1}
df["HeatingQC"]=df["HeatingQC"].map(d1)

# %%
ax=sns.countplot(df["CentralAir"],label="Count")

# %%
d2={"Y":1,"N":0}
df["CentralAir"]=df["CentralAir"].map(d2)

# %%
ax=sns.countplot(df["KitchenQual"],label="Count")

# %%
sns.countplot(df["HouseStyle"],label="Count")

# %%
d4={"1Story":1,"1.5Unf":2,"1.5Fin":4,"SFoyer":3,"SLvl":3,"2Story":5,"2.5Unf":6,"2.5Fin":7}
df["HouseStyle"]=df["HouseStyle"].map(d4)

# %%
sns.countplot(df["Fence"],label="Count")

# %% [markdown]
# <h2><br>Converting categorical data into numerical data by assigning their equivalent numerical values</h2>

# %%
d1={"Ex":5,"Gd":4,"TA":3,"Fa":2,"Po":1}
df["KitchenQual"]=df["KitchenQual"].map(d1)
d2={"MnPrv":0,"GdWo":2,"GdPrv":3,"MnWw":1}
df["Fence"]=df["Fence"].map(d2)

# %%
f2=['YearBuilt','GarageCars','TotalBsmtSF','GarageArea','Fireplaces','LotArea','FullBath','SaleType','SaleCondition','BldgType','TotRmsAbvGrd','PoolArea']

# %% [markdown]
# <hr>
# <h1><font color="navy blue"> Plotting graph between the percentage of amount of each subfeature present in the feature</font>
# </h1>

# %%
df_categorical = df
fig = plt.figure(figsize=(10,30))

for i, col in enumerate(df_categorical[f2]):   
   # PERCENT COLUMN CALCULATION
   df_categorical[col+'_pct'] = df_categorical.groupby([col])[col]\
                                   .transform(lambda x: len(x)) / len(df_categorical)*100

   plt.subplot(8, 2, i+1)   
   sns.barplot(x=col, y=col+'_pct', data=df_categorical)\
          .set(xlabel=col, ylabel='Percent')    

plt.tight_layout()
plt.show()
plt.clf()

plt.close('all')
# Out:
# C:\Users\Acer\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
d3={"1Fam":1,"2fmCon":2,"Duplex":3,"TwnhsE":5,"Twnhs":4}
df["BldgType"]=df["BldgType"].map(d3)
d4={"Normal":6,"Abnormal":5,"Partial":1,"AdjLand":4,"Alloca":2,"Family":3}
df["SaleCondition"]=df["SaleCondition"].map(d4)
d5={"C":5,"RH":4,"RM":3,"RL":2,"FV":1}
df["MSZoning"]=df["MSZoning"].map(d5)

# %% [markdown]
# <font size=12px> Finding the correlation of various features with the SalePrice</font>

# %%
print("Find most important features relative to target")
corr1= df.corr()
corr1.sort_values(["SalePrice"], ascending = False, inplace = True)
print(corr1.SalePrice)
# Out:
# Find most important features relative to target
# SalePrice            1.000000
# OverallQual          0.790982
# GrLivArea            0.708624
# KitchenQual          0.659600
# GarageCars           0.640409
# GarageArea           0.623431
# TotalBsmtSF          0.613581
# 1stFlrSF             0.605852
# FullBath             0.560664
# TotRmsAbvGrd         0.533723
# YearBuilt            0.522897
# YearRemodAdd         0.507101
# GarageYrBlt          0.486362
# MasVnrArea           0.477493
# Fireplaces           0.466929
# HeatingQC            0.427649
# BsmtFinSF1           0.386420
# LotFrontage          0.351799
# YearBuilt_pct        0.329653
# WoodDeckSF           0.324413
# 2ndFlrSF             0.319334
# OpenPorchSF          0.315856
# HalfBath             0.284108
# LotArea              0.263843
# CentralAir           0.251328
# BsmtFullBath         0.227122
# BsmtUnfSF            0.214479
# BedroomAbvGr         0.168213
# BldgType_pct         0.141623
# ...

# %% [markdown]
# <font style="Ariel"><h1>Plotting the barplot defined in seaborn between various features and SalePrice to see the effect of subfeature of the feature in the SalePrice</h1></font>
#
# <h3>Converting the categorical data into numerical data using mapping
# </h3

# %% [markdown]
# sns.barplot(df.ExterQual,df.SalePrice)

# %%
d1={"Gd":3,"TA":2,"Ex":4,"Fa":1}
df["ExterQual"]=df["ExterQual"].map(d1)

# %%
sns.barplot(df.LotShape,df.SalePrice)

# %%
d12={"IR2":4,"IR3":3,"IR1":2,"Reg":1}
df["LotShape"]=df["LotShape"].map(d12)

# %%
sns.barplot(df.Condition1,df.SalePrice)

# %%
d12={"PosN":8,"RRNn":7,"PosA":9,"RRNe":6,"Norm":5,"Feedr":3,"RRAe":2,"Artery":1,"RRAn":4}
df["Condition1"]=df["Condition1"].map(d12)

# %%
sns.barplot(df.Street,df.SalePrice)

# %%
d12={"Pave":2,"Grvl":1}
df["Street"]=df["Street"].map(d12)

# %%
sns.barplot(df.GarageFinish,df.SalePrice)

# %%
d6={"RFn":2,"Fin":3,"Unf":1}
df["GarageFinish"]=df["GarageFinish"].map(d6)

# %%
sns.barplot(df.Utilities,df.SalePrice)

# %%
d6={"AllPub":2,"NoSeWa":1}
df["Utilities"]=df["Utilities"].map(d6)

# %%
sns.barplot(df.MiscFeature,df.SalePrice)

# %%
d9={"TenC":4,"Gar2":3,"Shed":2,"Othr":1}
df["MiscFeature"]=df["MiscFeature"].map(d9)

# %%
sns.barplot(df.PoolQC,df.SalePrice)

# %%
d11={"Ex":3,"Fa":2,"Gd":1}
df["PoolQC"]=df["PoolQC"].map(d11)

# %%
sns.barplot(df.Heating,df.SalePrice)

# %%
d15={"GasA":6,"GasW":5,"OthW":4,"Wall":3,"Grav":2,"Floor":1}
df["Heating"]=df["Heating"].map(d15)

# %%
sns.barplot(df.HouseStyle,df.SalePrice)

# %%
sns.barplot(df.GarageCond,df.SalePrice)

# %%
d7={"Ex":5,"Gd":4,"TA":3,"Fa":2,"Po":1,"NA":0}
df["GarageCond"]=df["GarageCond"].map(d7)

# %%
sns.barplot(df.GarageQual,df.SalePrice)

# %%
d8={"Ex":5,"Gd":4,"TA":3,"Fa":2,"Po":1,"NA":0}
df["GarageQual"]=df["GarageQual"].map(d8)

# %%
sns.barplot(df.Electrical,df.SalePrice)

# %%
d9={"SBrkr":5,"FuseA":4,"FuseF":3,"FuseP":2,"Mix":1}
df["Electrical"]=df["Electrical"].map(d9)

# %%
sns.barplot(df.Functional,df.SalePrice)

# %%
d10={"Typ":7,"Mod":6,"Maj1":5,"Min1":4,"Min2":3,"Sev":2,"Maj2":1}
df["Functional"]=df["Functional"].map(d10)

# %%
sns.barplot(df.PavedDrive,df.SalePrice)

# %%
d13={"Y":3,"N":1,"P":2}
df["PavedDrive"]=df["PavedDrive"].map(d13)

# %%
sns.barplot(df.LandSlope,df.SalePrice)

# %%
d14={"Sev":3,"Mod":2,'Gtl':1}
df["LandSlope"]=df["LandSlope"].map(d14)

# %%
sns.barplot(df.FireplaceQu,df.SalePrice)

# %%
d8={"Ex":5,"Gd":4,"TA":3,"Fa":2,"Po":1}
df["FireplaceQu"]=df["FireplaceQu"].map(d8)

# %%
sns.barplot(df.BsmtCond,df.SalePrice)

# %%
d8={"Gd":4,"TA":3,"Fa":2,"Po":1}
df["BsmtCond"]=df["BsmtCond"].map(d8)

# %%
sns.barplot(df.BsmtExposure,df.SalePrice)

# %%
d18={"Gd":4,"Av":3,"Mn":2,"No":1}
df["BsmtExposure"]=df["BsmtExposure"].map(d18)

# %%
d4={"Lv1":2,"Bnk":1,"Low":3,"HLS":4}
df["LandContour"]=df["LandContour"].map(d4)

# %%
features=['SalePrice','ExterQual','GrLivArea','OverallQual','GarageArea','GarageCars','FullBath','HeatingQC','KitchenQual','YearBuilt']

# %% [markdown]
# <br>
# <h2 align="center">Correlation matrix</h2>
# <h3><font color ="green"> Plotting heat map between various features</font></h3>
# <br>
# <hr>

# %%
sns.heatmap(df[features].corr(), vmax=0.8, annot=True,cmap="RdYlGn");

# %% [markdown]
# <h2><font size =6px color="green">Ploting the pair plot among various features</font></h2>

# %%
sns.set()
sns.pairplot(df[features], height= 2.5)
plt.show();

# %% [markdown]
# <br>
# <h1 align="center"><font color="red" >Feature Engineering</font></h1>
# <h2><font color="green">
#    <br>
#     Assigning features to x and the target element to y
#     </font></h2>
#     <br>
#     <br>

# %%
features1=['GrLivArea','ExterQual','MasVnrArea','GarageYrBlt','YearRemodAdd','OverallQual','CentralAir','GarageArea','GarageCars','FullBath','HeatingQC','Fireplaces','KitchenQual','Fence','YearBuilt','SaleCondition','LotArea','LotFrontage','BldgType','BsmtFinSF1','2ndFlrSF','MSZoning','WoodDeckSF','YrSold','OpenPorchSF','BedroomAbvGr','GarageFinish','GarageCond','GarageQual','Utilities','HouseStyle','MiscFeature','Electrical','Functional','MiscVal','PoolQC','PoolArea','Street','FireplaceQu','Condition1','LotShape','KitchenAbvGr','Heating','PavedDrive','LandSlope','BsmtExposure','BsmtCond','BsmtFullBath','LowQualFinSF','HalfBath']
x=df[features1]
y=df["SalePrice"]

# %% [markdown]
# <h3><hr>
#     Finding the total NaN values/elements of all the features in X
#     </h3><br>

# %%
x.isnull().sum()
# Out:
# GrLivArea        0
# ExterQual        0
# MasVnrArea       0
# GarageYrBlt      0
# YearRemodAdd     0
# OverallQual      0
# CentralAir       0
# GarageArea       0
# GarageCars       0
# FullBath         0
# HeatingQC        0
# Fireplaces       0
# KitchenQual      0
# Fence            0
# YearBuilt        0
# SaleCondition    0
# LotArea          0
# LotFrontage      0
# BldgType         0
# BsmtFinSF1       0
# 2ndFlrSF         0
# MSZoning         0
# WoodDeckSF       0
# YrSold           0
# OpenPorchSF      0
# BedroomAbvGr     0
# GarageFinish     0
# GarageCond       0
# GarageQual       0
# Utilities        0
# HouseStyle       0
# MiscFeature      0
# Electrical       0
# Functional       0
# MiscVal          0
# PoolQC           0
# PoolArea         0
# Street           0
# FireplaceQu      0
# Condition1       0
# LotShape         0
# KitchenAbvGr     0
# Heating          0
# PavedDrive       0
# LandSlope        0
# BsmtExposure     0
# BsmtCond         0
# ...

# %% [markdown]
# <hr>
# <br><br>
# <h1 align="center"><font size=8px style="Ariel" color="red" >
#      CLEANING OF DATA
#     </font>
#     </h1>
#     <br>
#     </h3>Filling the missing categorical data with the median of the values of that feature
#     Filling the missing numerical data with the mean of the values of the data
#     Filling the missing some data like Fence,PoolQC,GarageQual with 0 by considering the reason behind the missing of the data
#     <br>
#     <br>

# %%
df["GarageYrBlt"]=df["GarageYrBlt"].fillna(df["GarageYrBlt"].mean())
df["MasVnrArea"]=df["MasVnrArea"].fillna(df["MasVnrArea"].mean())
df["Fence"]=df["Fence"].fillna(0)
df["LotFrontage"]=df["LotFrontage"].fillna(df["LotFrontage"].mean())
df["SaleCondition"]=df["SaleCondition"].fillna(df["LotFrontage"].median())
df["MSZoning"]=df["MSZoning"].fillna(df["MSZoning"].median())
df["GarageFinish"]=df["GarageFinish"].fillna(df["GarageFinish"].median())
df["GarageQual"]=df["GarageQual"].fillna(0)
df["GarageCond"]=df["GarageCond"].fillna(0)
df["Electrical"]=df["Electrical"].fillna(df["Electrical"].median())
df["PoolQC"]=df["PoolQC"].fillna(0)
df["MiscFeature"]=df["MiscFeature"].fillna(df["MiscFeature"].median())
df["FireplaceQu"]=df["FireplaceQu"].fillna(0)
df["BsmtCond"]=df["BsmtCond"].fillna(df["BsmtCond"].median())
df["BsmtExposure"]=df["BsmtExposure"].fillna(df["BsmtExposure"].median())

# %%
x.isnull().sum()
# Out:
# GrLivArea        0
# ExterQual        0
# MasVnrArea       0
# GarageYrBlt      0
# YearRemodAdd     0
# OverallQual      0
# CentralAir       0
# GarageArea       0
# GarageCars       0
# FullBath         0
# HeatingQC        0
# Fireplaces       0
# KitchenQual      0
# Fence            0
# YearBuilt        0
# SaleCondition    0
# LotArea          0
# LotFrontage      0
# BldgType         0
# BsmtFinSF1       0
# 2ndFlrSF         0
# MSZoning         0
# WoodDeckSF       0
# YrSold           0
# OpenPorchSF      0
# BedroomAbvGr     0
# GarageFinish     0
# GarageCond       0
# GarageQual       0
# Utilities        0
# HouseStyle       0
# MiscFeature      0
# Electrical       0
# Functional       0
# MiscVal          0
# PoolQC           0
# PoolArea         0
# Street           0
# FireplaceQu      0
# Condition1       0
# LotShape         0
# KitchenAbvGr     0
# Heating          0
# PavedDrive       0
# LandSlope        0
# BsmtExposure     0
# BsmtCond         0
# ...

# %% [markdown]
# <br>
# <font color='red'>
# <h1 align="center"> NORMALIZATION / SCALING OF THE DATA</h1></font>
# <BR>
# <HR>

# %%
from sklearn import preprocessing
from sklearn.preprocessing import StandardScaler
X=preprocessing.StandardScaler().fit(x).transform(x)
# Out:
# C:\Users\Acer\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:625: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\Acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   This is separate from the ipykernel package so we can avoid doing imports until

# %% [markdown]
# <br>
# <font color='red'>
# <h1>SPLITING OF THE DATA INTO TRAIN SET AND TEST SET</h1></font>
# <BR>
# <HR>

# %%
trainx,testx,trainy,testy=train_test_split(X,y,train_size=0.75)
# Out:
# C:\Users\Acer\Anaconda3\lib\site-packages\sklearn\model_selection\_split.py:2179: FutureWarning: From version 0.21, test_size will always complement train_size unless both are specified.
#   FutureWarning)

# %% [markdown]
# <BR>
# <HR>
# <font color="red" >
# <h1 align="center"> USING RANDOM FOREST REGRESSOR </h1></font>
# <br>
# <h2> Applying Random Forest Regressor on the train set to train the model and then using the model to evaluate the test set</h2>
# <BR>
# <HR>

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import r2_score
import math
k=0
t1=0
max=0
c=0

for i in range(3,150):
    clf=RandomForestRegressor(n_estimators=i,random_state=3)
    clf.fit(trainx,trainy)
    yhat=clf.predict(testx)
    t1=r2_score(testy,yhat)
    if(t1>max):
        max=t1
        k=i
    i=i+1
print(max)
print(k)
rmse=math.sqrt(np.mean(((yhat-testy)**2)))
print(math.log(rmse))
# Out:
# 0.8919191056263511
# 55
# 10.128660362177026

# %% [markdown]
# <BR>
#
# <font color="red" >
# <h1 align="center"><b> Regression Using Support Vector Machine </h1></font>
# <br>
#     <br>

# %%
from sklearn import svm
from sklearn.metrics import r2_score
max=-100
i=0
l=0
for i in range(3,10):
    clf2=svm.SVR(kernel='poly',degree=i,gamma='auto')
    clf2.fit(trainx,trainy)
    yhat2=clf2.predict(testx)
    b=clf2.score(testx,testy)
    if(max<b):
        max=b
        l=i
    i=i+1
print(max)
print(l)
# Out:
# -0.05002009473672042
# 5

# %% [markdown]
# <BR>
#
# <font color="red" >
# <h1 align="center"><b> Using Linear Regression </h1></font>
# <br>
#     <br>

# %%
from sklearn import linear_model
import statsmodels.api as sm
reg=linear_model.LinearRegression()
reg.fit(trainx,trainy)
model = sm.OLS(trainy,trainx).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:              SalePrice   R-squared:                       0.157
# Model:                            OLS   Adj. R-squared:                  0.117
# Method:                 Least Squares   F-statistic:                     3.895
# Date:                Wed, 03 Apr 2019   Prob (F-statistic):           5.41e-17
# Time:                        00:41:59   Log-Likelihood:                -14817.
# No. Observations:                1095   AIC:                         2.973e+04
# Df Residuals:                    1045   BIC:                         2.998e+04
# Df Model:                          50
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1          4.116e+04   1.56e+04      2.634      0.009    1.05e+04    7.18e+04
# ...

# %%
reg.score(testx,testy)
# Out:
# 0.6325442584138672

# %% [markdown]
# <BR>
#
# <h1>From  the above given model  we can see that Random forest Regressor is more efficient than Linear regression than Support Vector Regressor. </h1>
# <br>
#     <br>

# %% [markdown]
# <br>
# <h3>Using the whole train model to train the model
# </h3></br>

# %%
clf1=RandomForestRegressor(n_estimators=k,random_state=4)
clf1.fit(X,y)
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features='auto', max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators=55, n_jobs=None,
#            oob_score=False, random_state=4, verbose=0, warm_start=False)

# %% [markdown]
# <br>
# <font color="red" size=6 px><h1 align="center">Loading the test.csv file </h1></font>
# <br>

# %%
df1=pd.read_csv("test1.csv")
df1
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0     1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1     1462          20       RL         81.0    14267   Pave   NaN      IR1
# 2     1463          60       RL         74.0    13830   Pave   NaN      IR1
# 3     1464          60       RL         78.0     9978   Pave   NaN      IR1
# 4     1465         120       RL         43.0     5005   Pave   NaN      IR1
# 5     1466          60       RL         75.0    10000   Pave   NaN      IR1
# 6     1467          20       RL          NaN     7980   Pave   NaN      IR1
# 7     1468          60       RL         63.0     8402   Pave   NaN      IR1
# 8     1469          20       RL         85.0    10176   Pave   NaN      Reg
# 9     1470          20       RL         70.0     8400   Pave   NaN      Reg
# 10    1471         120       RH         26.0     5858   Pave   NaN      IR1
# ...

# %% [markdown]
# <BR>
# <H3> Finding the missing values of each columns </H3><BR>

# %%
df1[features1].isnull().sum()
# Out:
# GrLivArea           0
# ExterQual           0
# MasVnrArea         15
# GarageYrBlt        78
# YearRemodAdd        0
# OverallQual         0
# CentralAir          0
# GarageArea          1
# GarageCars          1
# FullBath            0
# HeatingQC           0
# Fireplaces          0
# KitchenQual         1
# Fence            1169
# YearBuilt           0
# SaleCondition       0
# LotArea             0
# LotFrontage       227
# BldgType            0
# BsmtFinSF1          1
# 2ndFlrSF            0
# MSZoning            4
# WoodDeckSF          0
# YrSold              0
# OpenPorchSF         0
# BedroomAbvGr        0
# GarageFinish       78
# GarageCond         78
# GarageQual         78
# Utilities           2
# HouseStyle          0
# MiscFeature      1408
# Electrical          0
# Functional          2
# MiscVal             0
# PoolQC           1456
# PoolArea            0
# Street              0
# FireplaceQu       730
# Condition1          0
# LotShape            0
# ...

# %% [markdown]
# <br>
# <h3>Converting the categorical data into numerical data using mapping
# </h3
# <br><br>

# %%
d3={"1Fam":1,"2fmCon":2,"Duplex":3,"TwnhsE":5,"Twnhs":4}
df1["BldgType"]=df1["BldgType"].map(d3)
d4={"Normal":6,"Abnormal":5,"Partial":1,"AdjLand":4,"Alloca":2,"Family":3}
df1["SaleCondition"]=df1["SaleCondition"].map(d4)
d5={"C":5,"RH":4,"RM":3,"RL":2,"FV":1}
df1["MSZoning"]=df1["MSZoning"].map(d5)
d1={"Gd":3,"TA":2,"Ex":4,"Fa":1}
df1["ExterQual"]=df1["ExterQual"].map(d1)
d1={"Ex":5,"Gd":4,"TA":3,"Fa":2,"Po":1}
df1["KitchenQual"]=df1["KitchenQual"].map(d1)
d2={"MnPrv":0,"GdWo":2,"GdPrv":3,"MnWw":1}
df1["Fence"]=df1["Fence"].map(d2)
d1={"Ex":5,"Gd":4,"TA":3,"Fa":2,"Po":1}
df1["HeatingQC"]=df1["HeatingQC"].map(d1)
d2={"Y":1,"N":0}
df1["CentralAir"]=df1["CentralAir"].map(d2)
d4={"1Story":1,"1.5Unf":2,"1.5Fin":4,"SFoyer":3,"SLvl":3,"2Story":5,"2.5Unf":6,"2.5Fin":7}
df1["HouseStyle"]=df1["HouseStyle"].map(d4)
d4={"Lv1":2,"Bnk":3,"Low":1,"HLS":4}
df1["LandContour"]=df1["LandContour"].map(d4)
d6={"RFn":3,"Fin":2,"Unf":1}
df1["GarageFinish"]=df1["GarageFinish"].map(d6)
d7={"Ex":5,"Gd":4,"TA":3,"Fa":2,"Po":1,"NA":0}
df1["GarageCond"]=df1["GarageCond"].map(d7)
d8={"Ex":5,"Gd":4,"TA":3,"Fa":2,"Po":1,"NA":0}
df1["GarageQual"]=df1["GarageQual"].map(d8)
d9={"AllPub":2,"NoSeWa":1}
df1["Utilities"]=df1["Utilities"].map(d9)
d9={"TenC":4,"Gar2":3,"Shed":2,"Othr":1}
df1["MiscFeature"]=df1["MiscFeature"].map(d9)
d9={"SBrkr":5,"FuseA":4,"FuseF":3,"FuseP":2,"Mix":1}
df1["Electrical"]=df1["Electrical"].map(d9)
d10={"Typ":7,"Mod":6,"Maj1":5,"Min1":4,"Min2":3,"Sev":2,"Maj2":1}
df1["Functional"]=df1["Functional"].map(d10)
d11={"Ex":3,"Fa":2,"Gd":1}
df1["PoolQC"]=df1["PoolQC"].map(d11)
d12={"Pave":2,"Grvl":1}
df1["Street"]=df1["Street"].map(d12)
d12={"PosN":8,"RRNn":7,"PosA":9,"RRNe":6,"Norm":5,"Feedr":3,"RRAe":2,"Artery":1,"RRAn":4}
df1["Condition1"]=df1["Condition1"].map(d12)
d12={"IR2":4,"IR3":3,"IR1":2,"Reg":1}
df1["LotShape"]=df1["LotShape"].map(d12)
d8={"Ex":5,"Gd":4,"TA":3,"Fa":2,"Po":1}
df1["FireplaceQu"]=df1["FireplaceQu"].map(d8)
d15={"GasA":6,"GasW":5,"OthW":4,"Wall":3,"Grav":2,"Floor":1}
df1["Heating"]=df1["Heating"].map(d15)
d14={"Sev":3,"Mod":2,'Gtl':1}
df1["LandSlope"]=df1["LandSlope"].map(d14)
d18={"Gd":4,"Av":3,"Mn":2,"No":1}
df1["BsmtExposure"]=df1["BsmtExposure"].map(d18)
d8={"Gd":4,"TA":3,"Fa":2,"Po":1}
df1["BsmtCond"]=df1["BsmtCond"].map(d8)
d13={"Y":3,"N":1,"P":2}
df1["PavedDrive"]=df1["PavedDrive"].map(d13)

# %% [markdown]
# <br>
# <h2 align="center" ><font color="brown">Converting the categorical data into numerical data using mapping
#     </font> </h2>
# <br><br>

# %%
df1["MasVnrArea"]=df1["MasVnrArea"].fillna(df1["MasVnrArea"].mean())
df1["Fence"]=df1["Fence"].fillna(0)
df1["LotFrontage"]=df1["LotFrontage"].fillna(df1["LotFrontage"].mean())
df1["SaleCondition"]=df1["SaleCondition"].fillna(df1["LotFrontage"].median())
df1["KitchenQual"]=df1["KitchenQual"].fillna(df1["KitchenQual"].median())
df1["GarageCars"]=df1["GarageCars"].fillna(0)
df1["GarageArea"]=df1["GarageArea"].fillna(0)
df1["GarageYrBlt"]=df1["GarageYrBlt"].fillna(df1["GarageYrBlt"].mean())
df1["BsmtFinSF1"]=df1["BsmtFinSF1"].fillna(0)
df1["GarageFinish"]=df1["GarageFinish"].fillna(df1["GarageFinish"].median())
df1["GarageFinish"]=df1["GarageFinish"].fillna(df1["GarageFinish"].median())
df1["GarageQual"]=df1["GarageQual"].fillna(0)
df1["GarageCond"]=df1["GarageCond"].fillna(0)
df1["MSZoning"]=df1["MSZoning"].fillna(df1["MSZoning"].median())
df1["Utilities"]=df1["Utilities"].fillna(1)
df1["Condition1"]=df1["Condition1"].fillna(0)
df1["FireplaceQu"]=df1["FireplaceQu"].fillna(0)
df1["MiscFeature"]=df1["MiscFeature"].fillna(df1["MiscFeature"].median())
df1["Functional"]=df1["Functional"].fillna(df1["Functional"].median())
df1["PoolQC"]=df1["PoolQC"].fillna(0)
df1["BsmtCond"]=df1["BsmtCond"].fillna(df1["BsmtCond"].median())
df1["BsmtExposure"]=df1["BsmtExposure"].fillna(df1["BsmtExposure"].median())
df1["BsmtFullBath"]=df1["BsmtFullBath"].fillna(df1["BsmtFullBath"].median())

# %%
df1[features1].isnull().sum()
# Out:
# GrLivArea        0
# ExterQual        0
# MasVnrArea       0
# GarageYrBlt      0
# YearRemodAdd     0
# OverallQual      0
# CentralAir       0
# GarageArea       0
# GarageCars       0
# FullBath         0
# HeatingQC        0
# Fireplaces       0
# KitchenQual      0
# Fence            0
# YearBuilt        0
# SaleCondition    0
# LotArea          0
# LotFrontage      0
# BldgType         0
# BsmtFinSF1       0
# 2ndFlrSF         0
# MSZoning         0
# WoodDeckSF       0
# YrSold           0
# OpenPorchSF      0
# BedroomAbvGr     0
# GarageFinish     0
# GarageCond       0
# GarageQual       0
# Utilities        0
# HouseStyle       0
# MiscFeature      0
# Electrical       0
# Functional       0
# MiscVal          0
# PoolQC           0
# PoolArea         0
# Street           0
# FireplaceQu      0
# Condition1       0
# LotShape         0
# KitchenAbvGr     0
# Heating          0
# PavedDrive       0
# LandSlope        0
# BsmtExposure     0
# BsmtCond         0
# ...

# %% [markdown]
# <br>
# <h1>Scaling of  features of the test data
# </h1><br><br>

# %%
tx=df1[features1]
from sklearn import preprocessing
from sklearn.preprocessing import StandardScaler
tX=preprocessing.StandardScaler().fit(tx).transform(tx)
# Out:
# C:\Users\Acer\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:625: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\Acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   after removing the cwd from sys.path.

# %% [markdown]
# <hr><br>
# <h1 align="center"><font size =5px color="green">Predicting the Sale Price of the given test model</font>
# </h1><br><br>

# %%
yhat1=clf1.predict(tX)
print(yhat1)
# Out:
# [122354.23636364 153444.54545455 185927.09090909 ... 158489.25454545
#  117062.72727273 234000.90909091]

# %% [markdown]
# <h1><font size=5px ><br><b>Creating a DataFrame named Submission consisting of ID and its corresponding Sale Price</font>
# </h1><br>

# %%
submission=pd.DataFrame({'Id':df1['Id'],'SalePrice':yhat1})
submission[10:20]
# Out:
#       Id      SalePrice
# 10  1471  188389.054545
# 11  1472   97863.636364
# 12  1473  101916.363636
# 13  1474  152803.636364
# 14  1475  138307.545455
# 15  1476  400850.581818
# 16  1477  267179.200000
# 17  1478  303351.509091
# 18  1479  273125.327273
# 19  1480  486824.963636

# %%
filename = 'House Price.csv'

submission.to_csv(filename,index=False)

print('Saved file: ' + filename)
# Out:
# Saved file: House Price.csv
